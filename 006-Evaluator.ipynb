# %% [markdown]
# <h1>MODEL EVALUATOR</h1>

# %%
#LOAD DEPENDENCIES
import os
import cv2
import time
import pickle
import logging
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

#Evaluation libraries
import itertools
import scikitplot 
import matplotlib.patheffects as path_effects
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_log_error
from sklearn.metrics import classification_report,confusion_matrix, roc_curve, auc, accuracy_score

#Model loader libraries
from pickle import load
from tensorflow.keras import applications
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras import Model, layers
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator

#PREVENT ERROR UNCESSARY MESSAGES
tf.get_logger().setLevel(logging.ERROR)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
#LOAD THE DATA
train_data_dir = "data/train/"
validation_data_dir = "data/val/"
test_data_dir = "data/test/"

img_rows, img_cols = 224, 224
input_shape = (img_rows,img_cols,3)
model_input = Input(shape=input_shape)

print("Data folders found!")
print("The Input size is set to ", model_input)
# Out:
# Data folders found!
# The Input size is set to  KerasTensor(type_spec=TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'")

# %%
#Assign the constants
batch_size = 8
epochs = 25

# %%
#DATA GENERATORS
val_datagen = ImageDataGenerator(rescale = 1. / 255)

test_datagen = ImageDataGenerator(rescale = 1. / 255)

validation_generator = val_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(img_rows,img_cols),
        batch_size=batch_size,
        class_mode='categorical',
        seed=42,
        shuffle=False,
        classes=['0_normal', 
                 '1_ulcerative_colitis', 
                 '2_polyps', 
                 '3_esophagitis'])

test_generator = test_datagen.flow_from_directory(
        test_data_dir,
        target_size=(img_rows,img_cols),
        batch_size=batch_size,
        class_mode='categorical',
        seed=42,
        shuffle=False,
        classes=['0_normal', 
                 '1_ulcerative_colitis', 
                 '2_polyps', 
                 '3_esophagitis'])

#CHECK  THE NUMBER OF SAMPLES
nb_validation_samples = len(validation_generator.filenames)
nb_test_samples = len(test_generator.filenames)

print("Validation samples:", nb_validation_samples)
print("Test samples:", nb_test_samples)

if nb_validation_samples == 0:
    print("NO DATA VALIDATION FOUND! Please check your validation data path and folders!")
    print("Check the data folders first!")
else:
    print("Validation samples found!")
    
if nb_test_samples == 0:
    print("NO DATA TEST FOUND! Please check your test data path and folders!")
    print("Check the data folders first!")
else:
    print("Test samples found!")

#check the class indices
validation_generator.class_indices
test_generator.class_indices

#true labels
Y_test=validation_generator.classes
test_labels = test_generator.classes

num_classes= len(validation_generator.class_indices)

print('Model set to train', num_classes, 'classes')

if nb_validation_samples and nb_test_samples > 0:
    print("Generators are set!")
    print("Check if dataset is complete and has no problems before proceeding.")
# Out:
# Found 2000 images belonging to 4 classes.
# Found 800 images belonging to 4 classes.
# Validation samples: 2000
# Test samples: 800
# Validation samples found!
# Test samples found!
# Model set to train 4 classes
# Generators are set!
# Check if dataset is complete and has no problems before proceeding.

# %%
#Load the model to evaluate

structure = ['MFuRe', 'MFNR']
dropout = ['alpha', 'standard', 'no']

#Select the model to evaluate by changing the values for architecture from 0-1 and condition from 0-2
architecture = structure[0]
condition = dropout[0] 

model = load_model('models/' + architecture + 'CNN' + '_'+ condition + '_do/' + 'model.h5')
print("**The model is successfully loaded**")
print("====================================")
print()
print("**Review as needed**")
print("------------------------------------")
model._name = architecture + 'CNN' + '_'+ condition + '_do'
model.summary()
# Out:
# **The model is successfully loaded**
# ====================================
#
# **Review as needed**
# ------------------------------------
# Model: "MFuReCNN_alpha_do"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1_DCNN_A_DCNN_B_DCNN_C_DC [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# rescaling_1_DCNN_A (Rescaling)  (None, 224, 224, 3)  0           input_1_DCNN_A_DCNN_B_DCNN_C_DCNN
# __________________________________________________________________________________________________
# normalization_1_DCNN_A (Normali (None, 224, 224, 3)  7           rescaling_1_DCNN_A[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad_DCNN_A (ZeroPaddi (None, 225, 225, 3)  0           normalization_1_DCNN_A[0][0]
# __________________________________________________________________________________________________
# stem_conv_DCNN_A (Conv2D)       (None, 112, 112, 32) 864         stem_conv_pad_DCNN_A[0][0]
# __________________________________________________________________________________________________
# stem_bn_DCNN_A (BatchNormalizat (None, 112, 112, 32) 128         stem_conv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# stem_activation_DCNN_A (Activat (None, 112, 112, 32) 0           stem_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv_DCNN_A (Depthwis (None, 112, 112, 32) 288         stem_activation_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block1a_bn_DCNN_A (BatchNormali (None, 112, 112, 32) 128         block1a_dwconv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block1a_activation_DCNN_A (Acti (None, 112, 112, 32) 0           block1a_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze_DCNN_A (Glob (None, 32)           0           block1a_activation_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape_DCNN_A (Resh (None, 1, 1, 32)     0           block1a_se_squeeze_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce_DCNN_A (Conv2 (None, 1, 1, 8)      264         block1a_se_reshape_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand_DCNN_A (Conv2 (None, 1, 1, 32)     288         block1a_se_reduce_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite_DCNN_A (Multi (None, 112, 112, 32) 0           block1a_activation_DCNN_A[0][0]
#                                                                  block1a_se_expand_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv_DCNN_A (Co (None, 112, 112, 16) 512         block1a_se_excite_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn_DCNN_A (Batc (None, 112, 112, 16) 64          block1a_project_conv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv_DCNN_A (Con (None, 112, 112, 96) 1536        block1a_project_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn_DCNN_A (Batch (None, 112, 112, 96) 384         block2a_expand_conv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation_DCNN_ (None, 112, 112, 96) 0           block2a_expand_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad_DCNN_A (Zero (None, 113, 113, 96) 0           block2a_expand_activation_DCNN_A[
# __________________________________________________________________________________________________
# block2a_dwconv_DCNN_A (Depthwis (None, 56, 56, 96)   864         block2a_dwconv_pad_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block2a_bn_DCNN_A (BatchNormali (None, 56, 56, 96)   384         block2a_dwconv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block2a_activation_DCNN_A (Acti (None, 56, 56, 96)   0           block2a_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze_DCNN_A (Glob (None, 96)           0           block2a_activation_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape_DCNN_A (Resh (None, 1, 1, 96)     0           block2a_se_squeeze_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce_DCNN_A (Conv2 (None, 1, 1, 4)      388         block2a_se_reshape_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand_DCNN_A (Conv2 (None, 1, 1, 96)     480         block2a_se_reduce_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite_DCNN_A (Multi (None, 56, 56, 96)   0           block2a_activation_DCNN_A[0][0]
#                                                                  block2a_se_expand_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv_DCNN_A (Co (None, 56, 56, 24)   2304        block2a_se_excite_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn_DCNN_A (Batc (None, 56, 56, 24)   96          block2a_project_conv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv_DCNN_A (Con (None, 56, 56, 144)  3456        block2a_project_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn_DCNN_A (Batch (None, 56, 56, 144)  576         block2b_expand_conv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation_DCNN_ (None, 56, 56, 144)  0           block2b_expand_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv_DCNN_A (Depthwis (None, 56, 56, 144)  1296        block2b_expand_activation_DCNN_A[
# __________________________________________________________________________________________________
# block2b_bn_DCNN_A (BatchNormali (None, 56, 56, 144)  576         block2b_dwconv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block2b_activation_DCNN_A (Acti (None, 56, 56, 144)  0           block2b_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze_DCNN_A (Glob (None, 144)          0           block2b_activation_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape_DCNN_A (Resh (None, 1, 1, 144)    0           block2b_se_squeeze_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce_DCNN_A (Conv2 (None, 1, 1, 6)      870         block2b_se_reshape_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand_DCNN_A (Conv2 (None, 1, 1, 144)    1008        block2b_se_reduce_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite_DCNN_A (Multi (None, 56, 56, 144)  0           block2b_activation_DCNN_A[0][0]
#                                                                  block2b_se_expand_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv_DCNN_A (Co (None, 56, 56, 24)   3456        block2b_se_excite_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn_DCNN_A (Batc (None, 56, 56, 24)   96          block2b_project_conv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block2b_drop_DCNN_A (Dropout)   (None, 56, 56, 24)   0           block2b_project_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block2b_add_DCNN_A (Add)        (None, 56, 56, 24)   0           block2b_drop_DCNN_A[0][0]
#                                                                  block2a_project_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv_DCNN_A (Con (None, 56, 56, 144)  3456        block2b_add_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn_DCNN_A (Batch (None, 56, 56, 144)  576         block3a_expand_conv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation_DCNN_ (None, 56, 56, 144)  0           block3a_expand_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad_DCNN_A (Zero (None, 59, 59, 144)  0           block3a_expand_activation_DCNN_A[
# __________________________________________________________________________________________________
# block3a_dwconv_DCNN_A (Depthwis (None, 28, 28, 144)  3600        block3a_dwconv_pad_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block3a_bn_DCNN_A (BatchNormali (None, 28, 28, 144)  576         block3a_dwconv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block3a_activation_DCNN_A (Acti (None, 28, 28, 144)  0           block3a_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze_DCNN_A (Glob (None, 144)          0           block3a_activation_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape_DCNN_A (Resh (None, 1, 1, 144)    0           block3a_se_squeeze_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce_DCNN_A (Conv2 (None, 1, 1, 6)      870         block3a_se_reshape_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand_DCNN_A (Conv2 (None, 1, 1, 144)    1008        block3a_se_reduce_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite_DCNN_A (Multi (None, 28, 28, 144)  0           block3a_activation_DCNN_A[0][0]
#                                                                  block3a_se_expand_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv_DCNN_A (Co (None, 28, 28, 40)   5760        block3a_se_excite_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn_DCNN_A (Batc (None, 28, 28, 40)   160         block3a_project_conv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv_DCNN_A (Con (None, 28, 28, 240)  9600        block3a_project_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn_DCNN_A (Batch (None, 28, 28, 240)  960         block3b_expand_conv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation_DCNN_ (None, 28, 28, 240)  0           block3b_expand_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv_DCNN_A (Depthwis (None, 28, 28, 240)  6000        block3b_expand_activation_DCNN_A[
# __________________________________________________________________________________________________
# block3b_bn_DCNN_A (BatchNormali (None, 28, 28, 240)  960         block3b_dwconv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block3b_activation_DCNN_A (Acti (None, 28, 28, 240)  0           block3b_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze_DCNN_A (Glob (None, 240)          0           block3b_activation_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape_DCNN_A (Resh (None, 1, 1, 240)    0           block3b_se_squeeze_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce_DCNN_A (Conv2 (None, 1, 1, 10)     2410        block3b_se_reshape_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand_DCNN_A (Conv2 (None, 1, 1, 240)    2640        block3b_se_reduce_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite_DCNN_A (Multi (None, 28, 28, 240)  0           block3b_activation_DCNN_A[0][0]
#                                                                  block3b_se_expand_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv_DCNN_A (Co (None, 28, 28, 40)   9600        block3b_se_excite_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn_DCNN_A (Batc (None, 28, 28, 40)   160         block3b_project_conv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block3b_drop_DCNN_A (Dropout)   (None, 28, 28, 40)   0           block3b_project_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block3b_add_DCNN_A (Add)        (None, 28, 28, 40)   0           block3b_drop_DCNN_A[0][0]
#                                                                  block3a_project_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4a_expand_conv_DCNN_A (Con (None, 28, 28, 240)  9600        block3b_add_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4a_expand_bn_DCNN_A (Batch (None, 28, 28, 240)  960         block4a_expand_conv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4a_expand_activation_DCNN_ (None, 28, 28, 240)  0           block4a_expand_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv_pad_DCNN_A (Zero (None, 29, 29, 240)  0           block4a_expand_activation_DCNN_A[
# __________________________________________________________________________________________________
# block4a_dwconv_DCNN_A (Depthwis (None, 14, 14, 240)  2160        block4a_dwconv_pad_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4a_bn_DCNN_A (BatchNormali (None, 14, 14, 240)  960         block4a_dwconv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4a_activation_DCNN_A (Acti (None, 14, 14, 240)  0           block4a_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze_DCNN_A (Glob (None, 240)          0           block4a_activation_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4a_se_reshape_DCNN_A (Resh (None, 1, 1, 240)    0           block4a_se_squeeze_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4a_se_reduce_DCNN_A (Conv2 (None, 1, 1, 10)     2410        block4a_se_reshape_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4a_se_expand_DCNN_A (Conv2 (None, 1, 1, 240)    2640        block4a_se_reduce_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4a_se_excite_DCNN_A (Multi (None, 14, 14, 240)  0           block4a_activation_DCNN_A[0][0]
#                                                                  block4a_se_expand_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4a_project_conv_DCNN_A (Co (None, 14, 14, 80)   19200       block4a_se_excite_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4a_project_bn_DCNN_A (Batc (None, 14, 14, 80)   320         block4a_project_conv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4b_expand_conv_DCNN_A (Con (None, 14, 14, 480)  38400       block4a_project_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4b_expand_bn_DCNN_A (Batch (None, 14, 14, 480)  1920        block4b_expand_conv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4b_expand_activation_DCNN_ (None, 14, 14, 480)  0           block4b_expand_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4b_dwconv_DCNN_A (Depthwis (None, 14, 14, 480)  4320        block4b_expand_activation_DCNN_A[
# __________________________________________________________________________________________________
# block4b_bn_DCNN_A (BatchNormali (None, 14, 14, 480)  1920        block4b_dwconv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4b_activation_DCNN_A (Acti (None, 14, 14, 480)  0           block4b_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4b_se_squeeze_DCNN_A (Glob (None, 480)          0           block4b_activation_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4b_se_reshape_DCNN_A (Resh (None, 1, 1, 480)    0           block4b_se_squeeze_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4b_se_reduce_DCNN_A (Conv2 (None, 1, 1, 20)     9620        block4b_se_reshape_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4b_se_expand_DCNN_A (Conv2 (None, 1, 1, 480)    10080       block4b_se_reduce_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4b_se_excite_DCNN_A (Multi (None, 14, 14, 480)  0           block4b_activation_DCNN_A[0][0]
#                                                                  block4b_se_expand_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4b_project_conv_DCNN_A (Co (None, 14, 14, 80)   38400       block4b_se_excite_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4b_project_bn_DCNN_A (Batc (None, 14, 14, 80)   320         block4b_project_conv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4b_drop_DCNN_A (Dropout)   (None, 14, 14, 80)   0           block4b_project_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4b_add_DCNN_A (Add)        (None, 14, 14, 80)   0           block4b_drop_DCNN_A[0][0]
#                                                                  block4a_project_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4c_expand_conv_DCNN_A (Con (None, 14, 14, 480)  38400       block4b_add_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4c_expand_bn_DCNN_A (Batch (None, 14, 14, 480)  1920        block4c_expand_conv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block4c_expand_activation_DCNN_ (None, 14, 14, 480)  0           block4c_expand_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# Conv1_DCNN_B (Conv2D)           (None, 112, 112, 32) 864         input_1_DCNN_A_DCNN_B_DCNN_C_DCNN
# __________________________________________________________________________________________________
# block4c_dwconv_DCNN_A (Depthwis (None, 14, 14, 480)  4320        block4c_expand_activation_DCNN_A[
# __________________________________________________________________________________________________
# bn_Conv1_DCNN_B (BatchNormaliza (None, 112, 112, 32) 128         Conv1_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block4c_bn_DCNN_A (BatchNormali (None, 14, 14, 480)  1920        block4c_dwconv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# Conv1_relu_DCNN_B (ReLU)        (None, 112, 112, 32) 0           bn_Conv1_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block4c_activation_DCNN_A (Acti (None, 14, 14, 480)  0           block4c_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_DCNN_B  (None, 112, 112, 32) 288         Conv1_relu_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block4c_se_squeeze_DCNN_A (Glob (None, 480)          0           block4c_activation_DCNN_A[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN_DCNN (None, 112, 112, 32) 128         expanded_conv_depthwise_DCNN_B[0]
# __________________________________________________________________________________________________
# block4c_se_reshape_DCNN_A (Resh (None, 1, 1, 480)    0           block4c_se_squeeze_DCNN_A[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu_DC (None, 112, 112, 32) 0           expanded_conv_depthwise_BN_DCNN_B
# __________________________________________________________________________________________________
# block4c_se_reduce_DCNN_A (Conv2 (None, 1, 1, 20)     9620        block4c_se_reshape_DCNN_A[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project_DCNN_B (C (None, 112, 112, 16) 512         expanded_conv_depthwise_relu_DCNN
# __________________________________________________________________________________________________
# block4c_se_expand_DCNN_A (Conv2 (None, 1, 1, 480)    10080       block4c_se_reduce_DCNN_A[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project_BN_DCNN_B (None, 112, 112, 16) 64          expanded_conv_project_DCNN_B[0][0
# __________________________________________________________________________________________________
# block4c_se_excite_DCNN_A (Multi (None, 14, 14, 480)  0           block4c_activation_DCNN_A[0][0]
#                                                                  block4c_se_expand_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_1_expand_DCNN_B (Conv2D)  (None, 112, 112, 96) 1536        expanded_conv_project_BN_DCNN_B[0
# __________________________________________________________________________________________________
# block4c_project_conv_DCNN_A (Co (None, 14, 14, 80)   38400       block4c_se_excite_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN_DCNN_B (Batch (None, 112, 112, 96) 384         block_1_expand_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block4c_project_bn_DCNN_A (Batc (None, 14, 14, 80)   320         block4c_project_conv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu_DCNN_B (ReL (None, 112, 112, 96) 0           block_1_expand_BN_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block4c_drop_DCNN_A (Dropout)   (None, 14, 14, 80)   0           block4c_project_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_1_pad_DCNN_B (ZeroPadding (None, 113, 113, 96) 0           block_1_expand_relu_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block4c_add_DCNN_A (Add)        (None, 14, 14, 80)   0           block4c_drop_DCNN_A[0][0]
#                                                                  block4b_add_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_DCNN_B (Depth (None, 56, 56, 96)   864         block_1_pad_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5a_expand_conv_DCNN_A (Con (None, 14, 14, 480)  38400       block4c_add_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN_DCNN_B (Ba (None, 56, 56, 96)   384         block_1_depthwise_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5a_expand_bn_DCNN_A (Batch (None, 14, 14, 480)  1920        block5a_expand_conv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu_DCNN_B ( (None, 56, 56, 96)   0           block_1_depthwise_BN_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5a_expand_activation_DCNN_ (None, 14, 14, 480)  0           block5a_expand_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_1_project_DCNN_B (Conv2D) (None, 56, 56, 24)   2304        block_1_depthwise_relu_DCNN_B[0][
# __________________________________________________________________________________________________
# block5a_dwconv_DCNN_A (Depthwis (None, 14, 14, 480)  12000       block5a_expand_activation_DCNN_A[
# __________________________________________________________________________________________________
# block_1_project_BN_DCNN_B (Batc (None, 56, 56, 24)   96          block_1_project_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5a_bn_DCNN_A (BatchNormali (None, 14, 14, 480)  1920        block5a_dwconv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_2_expand_DCNN_B (Conv2D)  (None, 56, 56, 144)  3456        block_1_project_BN_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5a_activation_DCNN_A (Acti (None, 14, 14, 480)  0           block5a_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN_DCNN_B (Batch (None, 56, 56, 144)  576         block_2_expand_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5a_se_squeeze_DCNN_A (Glob (None, 480)          0           block5a_activation_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu_DCNN_B (ReL (None, 56, 56, 144)  0           block_2_expand_BN_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5a_se_reshape_DCNN_A (Resh (None, 1, 1, 480)    0           block5a_se_squeeze_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_DCNN_B (Depth (None, 56, 56, 144)  1296        block_2_expand_relu_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5a_se_reduce_DCNN_A (Conv2 (None, 1, 1, 20)     9620        block5a_se_reshape_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN_DCNN_B (Ba (None, 56, 56, 144)  576         block_2_depthwise_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5a_se_expand_DCNN_A (Conv2 (None, 1, 1, 480)    10080       block5a_se_reduce_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu_DCNN_B ( (None, 56, 56, 144)  0           block_2_depthwise_BN_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5a_se_excite_DCNN_A (Multi (None, 14, 14, 480)  0           block5a_activation_DCNN_A[0][0]
#                                                                  block5a_se_expand_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_2_project_DCNN_B (Conv2D) (None, 56, 56, 24)   3456        block_2_depthwise_relu_DCNN_B[0][
# __________________________________________________________________________________________________
# block5a_project_conv_DCNN_A (Co (None, 14, 14, 112)  53760       block5a_se_excite_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN_DCNN_B (Batc (None, 56, 56, 24)   96          block_2_project_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5a_project_bn_DCNN_A (Batc (None, 14, 14, 112)  448         block5a_project_conv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_2_add_DCNN_B (Add)        (None, 56, 56, 24)   0           block_1_project_BN_DCNN_B[0][0]
#                                                                  block_2_project_BN_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5b_expand_conv_DCNN_A (Con (None, 14, 14, 672)  75264       block5a_project_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_3_expand_DCNN_B (Conv2D)  (None, 56, 56, 144)  3456        block_2_add_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5b_expand_bn_DCNN_A (Batch (None, 14, 14, 672)  2688        block5b_expand_conv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN_DCNN_B (Batch (None, 56, 56, 144)  576         block_3_expand_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5b_expand_activation_DCNN_ (None, 14, 14, 672)  0           block5b_expand_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu_DCNN_B (ReL (None, 56, 56, 144)  0           block_3_expand_BN_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5b_dwconv_DCNN_A (Depthwis (None, 14, 14, 672)  16800       block5b_expand_activation_DCNN_A[
# __________________________________________________________________________________________________
# block_3_pad_DCNN_B (ZeroPadding (None, 57, 57, 144)  0           block_3_expand_relu_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5b_bn_DCNN_A (BatchNormali (None, 14, 14, 672)  2688        block5b_dwconv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_DCNN_B (Depth (None, 28, 28, 144)  1296        block_3_pad_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5b_activation_DCNN_A (Acti (None, 14, 14, 672)  0           block5b_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN_DCNN_B (Ba (None, 28, 28, 144)  576         block_3_depthwise_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5b_se_squeeze_DCNN_A (Glob (None, 672)          0           block5b_activation_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu_DCNN_B ( (None, 28, 28, 144)  0           block_3_depthwise_BN_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5b_se_reshape_DCNN_A (Resh (None, 1, 1, 672)    0           block5b_se_squeeze_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_3_project_DCNN_B (Conv2D) (None, 28, 28, 32)   4608        block_3_depthwise_relu_DCNN_B[0][
# __________________________________________________________________________________________________
# block5b_se_reduce_DCNN_A (Conv2 (None, 1, 1, 28)     18844       block5b_se_reshape_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN_DCNN_B (Batc (None, 28, 28, 32)   128         block_3_project_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5b_se_expand_DCNN_A (Conv2 (None, 1, 1, 672)    19488       block5b_se_reduce_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_4_expand_DCNN_B (Conv2D)  (None, 28, 28, 192)  6144        block_3_project_BN_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5b_se_excite_DCNN_A (Multi (None, 14, 14, 672)  0           block5b_activation_DCNN_A[0][0]
#                                                                  block5b_se_expand_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN_DCNN_B (Batch (None, 28, 28, 192)  768         block_4_expand_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5b_project_conv_DCNN_A (Co (None, 14, 14, 112)  75264       block5b_se_excite_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu_DCNN_B (ReL (None, 28, 28, 192)  0           block_4_expand_BN_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5b_project_bn_DCNN_A (Batc (None, 14, 14, 112)  448         block5b_project_conv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_DCNN_B (Depth (None, 28, 28, 192)  1728        block_4_expand_relu_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5b_drop_DCNN_A (Dropout)   (None, 14, 14, 112)  0           block5b_project_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN_DCNN_B (Ba (None, 28, 28, 192)  768         block_4_depthwise_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5b_add_DCNN_A (Add)        (None, 14, 14, 112)  0           block5b_drop_DCNN_A[0][0]
#                                                                  block5a_project_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu_DCNN_B ( (None, 28, 28, 192)  0           block_4_depthwise_BN_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5c_expand_conv_DCNN_A (Con (None, 14, 14, 672)  75264       block5b_add_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_4_project_DCNN_B (Conv2D) (None, 28, 28, 32)   6144        block_4_depthwise_relu_DCNN_B[0][
# __________________________________________________________________________________________________
# block5c_expand_bn_DCNN_A (Batch (None, 14, 14, 672)  2688        block5c_expand_conv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN_DCNN_B (Batc (None, 28, 28, 32)   128         block_4_project_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5c_expand_activation_DCNN_ (None, 14, 14, 672)  0           block5c_expand_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_4_add_DCNN_B (Add)        (None, 28, 28, 32)   0           block_3_project_BN_DCNN_B[0][0]
#                                                                  block_4_project_BN_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5c_dwconv_DCNN_A (Depthwis (None, 14, 14, 672)  16800       block5c_expand_activation_DCNN_A[
# __________________________________________________________________________________________________
# block_5_expand_DCNN_B (Conv2D)  (None, 28, 28, 192)  6144        block_4_add_DCNN_B[0][0]
# __________________________________________________________________________________________________
# block5c_bn_DCNN_A (BatchNormali (None, 14, 14, 672)  2688        block5c_dwconv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN_DCNN_B (Batch (None, 28, 28, 192)  768         block_5_expand_DCNN_B[0][0]
# __________________________________________________________________________________________________
# conv1_pad_DCNN_C (ZeroPadding2D (None, 230, 230, 3)  0           input_1_DCNN_A_DCNN_B_DCNN_C_DCNN
# __________________________________________________________________________________________________
# block5c_activation_DCNN_A (Acti (None, 14, 14, 672)  0           block5c_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu_DCNN_B (ReL (None, 28, 28, 192)  0           block_5_expand_BN_DCNN_B[0][0]
# __________________________________________________________________________________________________
# conv1_conv_DCNN_C (Conv2D)      (None, 112, 112, 64) 9472        conv1_pad_DCNN_C[0][0]
# __________________________________________________________________________________________________
# block5c_se_squeeze_DCNN_A (Glob (None, 672)          0           block5c_activation_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_DCNN_B (Depth (None, 28, 28, 192)  1728        block_5_expand_relu_DCNN_B[0][0]
# __________________________________________________________________________________________________
# pool1_pad_DCNN_C (ZeroPadding2D (None, 114, 114, 64) 0           conv1_conv_DCNN_C[0][0]
# __________________________________________________________________________________________________
# block5c_se_reshape_DCNN_A (Resh (None, 1, 1, 672)    0           block5c_se_squeeze_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN_DCNN_B (Ba (None, 28, 28, 192)  768         block_5_depthwise_DCNN_B[0][0]
# __________________________________________________________________________________________________
# pool1_pool_DCNN_C (MaxPooling2D (None, 56, 56, 64)   0           pool1_pad_DCNN_C[0][0]
# __________________________________________________________________________________________________
# block5c_se_reduce_DCNN_A (Conv2 (None, 1, 1, 28)     18844       block5c_se_reshape_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu_DCNN_B ( (None, 28, 28, 192)  0           block_5_depthwise_BN_DCNN_B[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_bn_DCNN_C ( (None, 56, 56, 64)   256         pool1_pool_DCNN_C[0][0]
# __________________________________________________________________________________________________
# block5c_se_expand_DCNN_A (Conv2 (None, 1, 1, 672)    19488       block5c_se_reduce_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_5_project_DCNN_B (Conv2D) (None, 28, 28, 32)   6144        block_5_depthwise_relu_DCNN_B[0][
# __________________________________________________________________________________________________
# conv2_block1_preact_relu_DCNN_C (None, 56, 56, 64)   0           conv2_block1_preact_bn_DCNN_C[0][
# __________________________________________________________________________________________________
# block5c_se_excite_DCNN_A (Multi (None, 14, 14, 672)  0           block5c_activation_DCNN_A[0][0]
#                                                                  block5c_se_expand_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN_DCNN_B (Batc (None, 28, 28, 32)   128         block_5_project_DCNN_B[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv_DCNN_C (Con (None, 56, 56, 64)   4096        conv2_block1_preact_relu_DCNN_C[0
# __________________________________________________________________________________________________
# block5c_project_conv_DCNN_A (Co (None, 14, 14, 112)  75264       block5c_se_excite_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_5_add_DCNN_B (Add)        (None, 28, 28, 32)   0           block_4_add_DCNN_B[0][0]
#                                                                  block_5_project_BN_DCNN_B[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn_DCNN_C (Batch (None, 56, 56, 64)   256         conv2_block1_1_conv_DCNN_C[0][0]
# __________________________________________________________________________________________________
# block5c_project_bn_DCNN_A (Batc (None, 14, 14, 112)  448         block5c_project_conv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_6_expand_DCNN_B (Conv2D)  (None, 28, 28, 192)  6144        block_5_add_DCNN_B[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu_DCNN_C (Act (None, 56, 56, 64)   0           conv2_block1_1_bn_DCNN_C[0][0]
# __________________________________________________________________________________________________
# block5c_drop_DCNN_A (Dropout)   (None, 14, 14, 112)  0           block5c_project_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN_DCNN_B (Batch (None, 28, 28, 192)  768         block_6_expand_DCNN_B[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_pad_DCNN_C (Zero (None, 58, 58, 64)   0           conv2_block1_1_relu_DCNN_C[0][0]
# __________________________________________________________________________________________________
# block5c_add_DCNN_A (Add)        (None, 14, 14, 112)  0           block5c_drop_DCNN_A[0][0]
#                                                                  block5b_add_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu_DCNN_B (ReL (None, 28, 28, 192)  0           block_6_expand_BN_DCNN_B[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv_DCNN_C (Con (None, 56, 56, 64)   36864       conv2_block1_2_pad_DCNN_C[0][0]
# __________________________________________________________________________________________________
# block6a_expand_conv_DCNN_A (Con (None, 14, 14, 672)  75264       block5c_add_DCNN_A[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# block6c_project_bn_DCNN_A (Batc (None, 7, 7, 192)    768         block6c_project_conv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_11_expand_DCNN_B (Conv2D) (None, 14, 14, 576)  55296       block_10_project_BN_DCNN_B[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu_DCNN_C (Act (None, 28, 28, 128)  0           conv3_block2_1_bn_DCNN_C[0][0]
# __________________________________________________________________________________________________
# block6c_drop_DCNN_A (Dropout)   (None, 7, 7, 192)    0           block6c_project_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN_DCNN_B (Batc (None, 14, 14, 576)  2304        block_11_expand_DCNN_B[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_pad_DCNN_C (Zero (None, 30, 30, 128)  0           conv3_block2_1_relu_DCNN_C[0][0]
# __________________________________________________________________________________________________
# block6c_add_DCNN_A (Add)        (None, 7, 7, 192)    0           block6c_drop_DCNN_A[0][0]
#                                                                  block6b_add_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu_DCNN_B (Re (None, 14, 14, 576)  0           block_11_expand_BN_DCNN_B[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv_DCNN_C (Con (None, 28, 28, 128)  147456      conv3_block2_2_pad_DCNN_C[0][0]
# __________________________________________________________________________________________________
# block6d_expand_conv_DCNN_A (Con (None, 7, 7, 1152)   221184      block6c_add_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_DCNN_B (Dept (None, 14, 14, 576)  5184        block_11_expand_relu_DCNN_B[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn_DCNN_C (Batch (None, 28, 28, 128)  512         conv3_block2_2_conv_DCNN_C[0][0]
# __________________________________________________________________________________________________
# block6d_expand_bn_DCNN_A (Batch (None, 7, 7, 1152)   4608        block6d_expand_conv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN_DCNN_B (B (None, 14, 14, 576)  2304        block_11_depthwise_DCNN_B[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu_DCNN_C (Act (None, 28, 28, 128)  0           conv3_block2_2_bn_DCNN_C[0][0]
# __________________________________________________________________________________________________
# block6d_expand_activation_DCNN_ (None, 7, 7, 1152)   0           block6d_expand_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu_DCNN_B  (None, 14, 14, 576)  0           block_11_depthwise_BN_DCNN_B[0][0
# __________________________________________________________________________________________________
# conv3_block2_3_conv_DCNN_C (Con (None, 28, 28, 512)  66048       conv3_block2_2_relu_DCNN_C[0][0]
# __________________________________________________________________________________________________
# block6d_dwconv_DCNN_A (Depthwis (None, 7, 7, 1152)   28800       block6d_expand_activation_DCNN_A[
# __________________________________________________________________________________________________
# block_11_project_DCNN_B (Conv2D (None, 14, 14, 96)   55296       block_11_depthwise_relu_DCNN_B[0]
# __________________________________________________________________________________________________
# conv3_block2_out_DCNN_C (Add)   (None, 28, 28, 512)  0           conv3_block1_out_DCNN_C[0][0]
#                                                                  conv3_block2_3_conv_DCNN_C[0][0]
# __________________________________________________________________________________________________
# block6d_bn_DCNN_A (BatchNormali (None, 7, 7, 1152)   4608        block6d_dwconv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN_DCNN_B (Bat (None, 14, 14, 96)   384         block_11_project_DCNN_B[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_bn_DCNN_C ( (None, 28, 28, 512)  2048        conv3_block2_out_DCNN_C[0][0]
# __________________________________________________________________________________________________
# block6d_activation_DCNN_A (Acti (None, 7, 7, 1152)   0           block6d_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_11_add_DCNN_B (Add)       (None, 14, 14, 96)   0           block_10_project_BN_DCNN_B[0][0]
#                                                                  block_11_project_BN_DCNN_B[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_relu_DCNN_C (None, 28, 28, 512)  0           conv3_block3_preact_bn_DCNN_C[0][
# __________________________________________________________________________________________________
# block6d_se_squeeze_DCNN_A (Glob (None, 1152)         0           block6d_activation_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_12_expand_DCNN_B (Conv2D) (None, 14, 14, 576)  55296       block_11_add_DCNN_B[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv_DCNN_C (Con (None, 28, 28, 128)  65536       conv3_block3_preact_relu_DCNN_C[0
# __________________________________________________________________________________________________
# block6d_se_reshape_DCNN_A (Resh (None, 1, 1, 1152)   0           block6d_se_squeeze_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN_DCNN_B (Batc (None, 14, 14, 576)  2304        block_12_expand_DCNN_B[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn_DCNN_C (Batch (None, 28, 28, 128)  512         conv3_block3_1_conv_DCNN_C[0][0]
# __________________________________________________________________________________________________
# block6d_se_reduce_DCNN_A (Conv2 (None, 1, 1, 48)     55344       block6d_se_reshape_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu_DCNN_B (Re (None, 14, 14, 576)  0           block_12_expand_BN_DCNN_B[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu_DCNN_C (Act (None, 28, 28, 128)  0           conv3_block3_1_bn_DCNN_C[0][0]
# __________________________________________________________________________________________________
# block6d_se_expand_DCNN_A (Conv2 (None, 1, 1, 1152)   56448       block6d_se_reduce_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_DCNN_B (Dept (None, 14, 14, 576)  5184        block_12_expand_relu_DCNN_B[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_pad_DCNN_C (Zero (None, 30, 30, 128)  0           conv3_block3_1_relu_DCNN_C[0][0]
# __________________________________________________________________________________________________
# block6d_se_excite_DCNN_A (Multi (None, 7, 7, 1152)   0           block6d_activation_DCNN_A[0][0]
#                                                                  block6d_se_expand_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN_DCNN_B (B (None, 14, 14, 576)  2304        block_12_depthwise_DCNN_B[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv_DCNN_C (Con (None, 28, 28, 128)  147456      conv3_block3_2_pad_DCNN_C[0][0]
# __________________________________________________________________________________________________
# block6d_project_conv_DCNN_A (Co (None, 7, 7, 192)    221184      block6d_se_excite_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu_DCNN_B  (None, 14, 14, 576)  0           block_12_depthwise_BN_DCNN_B[0][0
# __________________________________________________________________________________________________
# conv3_block3_2_bn_DCNN_C (Batch (None, 28, 28, 128)  512         conv3_block3_2_conv_DCNN_C[0][0]
# __________________________________________________________________________________________________
# block6d_project_bn_DCNN_A (Batc (None, 7, 7, 192)    768         block6d_project_conv_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_12_project_DCNN_B (Conv2D (None, 14, 14, 96)   55296       block_12_depthwise_relu_DCNN_B[0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu_DCNN_C (Act (None, 28, 28, 128)  0           conv3_block3_2_bn_DCNN_C[0][0]
# __________________________________________________________________________________________________
# block6d_drop_DCNN_A (Dropout)   (None, 7, 7, 192)    0           block6d_project_bn_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN_DCNN_B (Bat (None, 14, 14, 96)   384         block_12_project_DCNN_B[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv_DCNN_C (Con (None, 28, 28, 512)  66048       conv3_block3_2_relu_DCNN_C[0][0]
# __________________________________________________________________________________________________
# block6d_add_DCNN_A (Add)        (None, 7, 7, 192)    0           block6d_drop_DCNN_A[0][0]
#                                                                  block6c_add_DCNN_A[0][0]
# __________________________________________________________________________________________________
# block_12_add_DCNN_B (Add)       (None, 14, 14, 96)   0           block_11_add_DCNN_B[0][0]
#                                                                  block_12_project_BN_DCNN_B[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out_DCNN_C (Add)   (None, 28, 28, 512)  0           conv3_block2_out_DCNN_C[0][0]
#                                                                  conv3_block3_3_conv_DCNN_C[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 7, 7, 192)    37056       block6d_add_DCNN_A[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 7, 7, 192)    1179840     block_12_add_DCNN_B[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 23, 23, 192)  3539136     conv3_block3_out_DCNN_C[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 7, 7, 192)    0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 7, 7, 192)    0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 7, 7, 192)    0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# alpha_dropout_3 (AlphaDropout)  (None, 7, 7, 192)    0           average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# alpha_dropout_4 (AlphaDropout)  (None, 7, 7, 192)    0           average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# alpha_dropout_5 (AlphaDropout)  (None, 7, 7, 192)    0           average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# FusionLayer (Add)               (None, 7, 7, 192)    0           alpha_dropout_3[0][0]
#                                                                  alpha_dropout_4[0][0]
#                                                                  alpha_dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 7, 7, 192)    768         FusionLayer[0][0]
# __________________________________________________________________________________________________
# tf.nn.selu (TFOpLambda)         (None, 7, 7, 192)    0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 7, 7, 192)    37056       tf.nn.selu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 7, 7, 192)    768         conv2d_6[0][0]
# __________________________________________________________________________________________________
# tf.nn.selu_1 (TFOpLambda)       (None, 7, 7, 192)    0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 7, 7, 192)    37056       tf.nn.selu_1[0][0]
# __________________________________________________________________________________________________
# ResidualFusionLayer (Add)       (None, 7, 7, 192)    0           FusionLayer[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 192)          0           ResidualFusionLayer[0][0]
# __________________________________________________________________________________________________
# alpha_dropout_6 (AlphaDropout)  (None, 192)          0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# Softmax_ClassifierMFRCNN_selu ( (None, 4)            772         alpha_dropout_6[0][0]
# ==================================================================================================
# Total params: 9,474,935
# Trainable params: 4,831,684
# Non-trainable params: 4,643,251
# __________________________________________________________________________________________________

# %% [markdown]
# **INITIAL CHECKING**

# %%
#Sanity evaluation for validation dataset
model.evaluate(validation_generator, return_dict = True)
# Out:
# 250/250 [==============================] - 17s 53ms/step - loss: 0.1318 - accuracy: 0.9665
# {'loss': 0.13176731765270233, 'accuracy': 0.9664999842643738}

# %%
#Sanity evaluation for test dataset
model.evaluate(test_generator, return_dict = True)
# Out:
# 100/100 [==============================] - 5s 54ms/step - loss: 0.0921 - accuracy: 0.9775
# {'loss': 0.09214909374713898, 'accuracy': 0.9775000214576721}

# %% [markdown]
# **VISUALIZATIONS**

# %%
#Modify only as needed

#Figure
dpi = 1000
plt.rcParams.update({'figure.dpi': dpi})
figsize = (12, 12)

#Markers
marker_train_accuracy = 's'
marker_validation_accuracy = 'x'
marker_train_loss = 'o'
marker_validation_loss = '|'
marker_fillstyle_train = 'none'
marker_fillstyle_validation = 'none'
marker_plot_markersize = 25
marker_plot_markerwidth = 3

#Lines
line_style_train = '-' 
line_style_validation = '--'
line_width_train = '5'
line_width_val = line_width_train
line_color_train_accuracy = 'black'
line_color_val_accuracy = 'black'
line_color_train_loss = 'black'
line_color_val_loss = 'black'

#Labels
train_accuracy_label = 'Train ' + 'Acc'
validation_accuracy_label = 'Val ' + 'Acc'
train_loss_label = 'Train ' + 'Loss'
validation_loss_label = 'Val ' 'Loss'
x_label_font_size = 56
y_label_font_size = x_label_font_size
x_label_font = 'Tahoma'
y_label_font = x_label_font
# x_label_fontweight = 'bold'
# y_label_fontweight = x_label_fontweight

#Ticks
spine_axis_thickness = 4
tick_font_size = 42
tick_length = 12
tick_width = spine_axis_thickness

#Legend
legend_border_pad = 0.35
legend_line_width = 5
legend_font_size = 50
legend_edge_color = 'black'
legend_label_spacing = 0.5
legend_location = 'best'
legend_ncol = 1
legend_font = 'Tahoma'
legend_has_frame = True

#saver
image_format = '.tiff'
figure_path = "figures/"

#Be careful when changing
acc_loss_save = figure_path + architecture + 'CNN' + '_'+ condition + '_do' + "/00-val_accuracy_loss" + image_format
val_cm_save = figure_path + architecture + 'CNN' + '_'+ condition + '_do' "/01-val_cm" + image_format
val_norm_cm_save = figure_path + architecture + 'CNN' + '_'+ condition + '_do' "/02-norm_val_cm" + image_format
test_cm_save = figure_path + architecture + 'CNN' + '_'+ condition + '_do' "/03-test_cm" + image_format
test_norm_cm_save = figure_path + architecture + 'CNN' + '_'+ condition + '_do' "/04-norm_test_cm" + image_format
val_roc_save = figure_path + architecture + 'CNN' + '_'+ condition + '_do' "/05-val_roc" + image_format
val_pr_save = figure_path + architecture + 'CNN' + '_'+ condition + '_do' "/06-val_pr" + image_format
test_roc_save = figure_path + architecture + 'CNN' + '_'+ condition + '_do' "/07-test_roc" + image_format
test_pr_save = figure_path + architecture + 'CNN' + '_'+ condition + '_do' "/08-pr_roc" + image_format

# %%
#Load history
history = load(open('models/' + architecture + 'CNN' + '_'+ condition + '_do/' + 'model.history', 'rb'))
print("The History is Loaded")
# Out:
# The History is Loaded

# %%
#Convergence

plt.style.use("default")
plt.figure(figsize = figsize, 
           dpi = 600, 
           edgecolor = 'black', 
           facecolor = 'white', 
           linewidth = 0)

plt.tight_layout()
plt.rc('xtick', labelsize = tick_font_size, direction="in") 
plt.rc('ytick', labelsize = tick_font_size, direction="in") 

fig, ax = plt.subplots(figsize = figsize)
plt.gcf().subplots_adjust(bottom = 0.15)
plt.setp(ax.spines.values(), linewidth = spine_axis_thickness)

plt.tick_params(length = tick_length, 
                width = tick_width, 
                right = True, 
                top = True)

plt.plot(np.arange(1, epochs + 1), 
         history["accuracy"], 
         mew = marker_plot_markerwidth, 
         color = line_color_train_accuracy, 
         lw = line_width_train, 
         marker = marker_train_accuracy, 
         markersize = marker_plot_markersize, 
         fillstyle = marker_fillstyle_train, 
         ls = line_style_train, 
         label = train_accuracy_label)

plt.plot(np.arange(1, epochs + 1), 
         history["val_accuracy"], 
         mew = marker_plot_markerwidth, 
         color = line_color_val_accuracy, 
         lw = line_width_val, 
         marker = marker_validation_accuracy, 
         markersize = marker_plot_markersize, 
         fillstyle = marker_fillstyle_validation, 
         ls = line_style_validation,  
         label = validation_accuracy_label)

plt.plot(np.arange(1, epochs + 1), 
         history["loss"], 
         mew = marker_plot_markerwidth, 
         color = line_color_train_loss, 
         lw = line_width_train, 
         marker = marker_train_loss, 
         markersize = marker_plot_markersize, 
         fillstyle = marker_fillstyle_train, 
         ls = line_style_train, label = train_loss_label)

plt.plot(np.arange(1, epochs + 1), 
         history["val_loss"], 
         mew = marker_plot_markerwidth, 
         color = line_color_val_loss, 
         lw = line_width_val, 
         marker = marker_validation_loss, 
         markersize = marker_plot_markersize, 
         fillstyle = marker_fillstyle_validation, 
         ls = line_style_validation,  
         label = validation_loss_label)

plt.xlabel("Epochs", fontfamily = x_label_font, fontsize = x_label_font_size, color ='black')
plt.ylabel("Accuracy/Loss", fontfamily = y_label_font, fontsize = y_label_font_size, color = 'black')

legend = plt.legend(loc = legend_location, 
                    ncol = legend_ncol, 
                    frameon = legend_has_frame, 
                    fontsize=legend_font_size, 
                    edgecolor=legend_edge_color, 
                    borderpad=legend_border_pad, 
                    labelspacing=legend_label_spacing)

frame = legend.get_frame()
legend.get_frame().set_linewidth(legend_line_width)
legend.get_frame().set_edgecolor(legend_edge_color)
plt.setp(legend.texts, family = legend_font)
plt.tight_layout()

plt.savefig(acc_loss_save, 
            bbox_inches='tight', 
            dpi=dpi)

# %%
# Validation Results

#evaluate accuracy
y_pred = model.predict(validation_generator,
                                 nb_validation_samples/batch_size, workers=1)

accuracy = accuracy_score(Y_test, y_pred.argmax(axis=-1))
print('The accuracy of the model is: ', accuracy)

#evaluate mean squared error
mse = mean_squared_error(Y_test, y_pred.argmax(axis=-1))
print('The Mean Squared Error of the model is: ', mse)

#evaluate mean squared log error
msle = mean_squared_log_error(Y_test, y_pred.argmax(axis=-1))  
print('The Mean Squared Log Error of the model is: ', msle)
# Out:
# The accuracy of the model is:  0.9665
# The Mean Squared Error of the model is:  0.047
# The Mean Squared Log Error of the model is:  0.010472583070873199

# %%
# Test Results

#evaluate accuracy
test_pred = model.predict(test_generator,
                                 nb_test_samples/batch_size, workers=1)

test_accuracy = accuracy_score(test_labels, test_pred.argmax(axis=-1))
print('The accuracy of the model is: ', test_accuracy)

#evaluate mean squared error
test_mse = mean_squared_error(test_labels, test_pred.argmax(axis=-1))
print('The Mean Squared Error of the model is: ', test_mse)

#evaluate mean squared log error
test_msle = mean_squared_log_error(test_labels, test_pred.argmax(axis=-1))  
print('The Mean Squared Log Error of the model is: ', test_msle)
# Out:
# The accuracy of the model is:  0.9775
# The Mean Squared Error of the model is:  0.03375
# The Mean Squared Log Error of the model is:  0.006069426912783993

# %%
# Confusion Matrix (Normalized)

fontsize=12

def confusion_matrix_test(cm, classes,
                          normalize=True, #if true all values in confusion matrix is between 0 and 1
                          title=architecture + 'CNN ' + condition + ' ' + 'do' + ' Val',
                          cmap=plt.cm.binary):

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=18)
    plt.colorbar(orientation='vertical')
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=0, fontfamily = 'Tahoma', fontsize=fontsize, horizontalalignment="center")
    plt.yticks(tick_marks, classes, rotation=0, fontfamily = 'Tahoma', fontsize=fontsize, verticalalignment="center")

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        text = plt.text(j, i, '{:.2f}%'.format(cm[i, j]*100),
                 fontfamily = 'Tahoma', 
                 fontsize=9, weight='bold',
                 horizontalalignment="center", verticalalignment='center',
                 color="white" if cm[i, j] > thresh else "white")
        text.set_path_effects([path_effects.Stroke(linewidth=1, foreground='black'), 
        path_effects.Normal()]),

    
    plt.tight_layout()
    plt.ylabel('True label', fontfamily = 'Tahoma', fontsize=18, horizontalalignment="center")
    plt.xlabel('Predicted label', fontfamily = 'Tahoma', fontsize=18)

#print classification report and plot confusion matrix
plt.style.use("default")
target_names = ['Normal', 'Ulcer', 'Polyps', 'Esophagitis']
print(classification_report(Y_test,y_pred.argmax(axis=-1),
                            target_names=target_names, digits=4))

# Compute confusion matrix
cnf_matrix_test = confusion_matrix(Y_test,y_pred.argmax(axis=-1))
np.set_printoptions(precision=4)

# Plot non-normalized confusion matrix
plt.figure(figsize=(5.25, 5.25), dpi=600)
confusion_matrix_test(cnf_matrix_test, classes=target_names)
plt.tight_layout()

plt.savefig(val_cm_save, 
            bbox_inches='tight', 
            dpi=dpi)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#       Normal     0.9939    0.9700    0.9818       500
#        Ulcer     0.9400    0.9400    0.9400       500
#       Polyps     0.9466    0.9580    0.9523       500
#  Esophagitis     0.9862    0.9980    0.9920       500
#
#     accuracy                         0.9665      2000
#    macro avg     0.9667    0.9665    0.9665      2000
# weighted avg     0.9667    0.9665    0.9665      2000
#
# Normalized confusion matrix
# [[0.97  0.028 0.002 0.   ]
#  [0.    0.94  0.052 0.008]
#  [0.006 0.03  0.958 0.006]
#  [0.    0.002 0.    0.998]]

# %%
#Confusion Matrix

fontsize=12

def confusion_matrix_test(cm, classes,
                          normalize=False, #if true all values in confusion matrix is between 0 and 1
                          title=architecture + 'CNN ' + condition + ' ' + 'do' + ' Val',
                          cmap=plt.cm.binary):

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=18)
    plt.colorbar(orientation='vertical')
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=0, fontfamily = 'Tahoma', fontsize=fontsize, horizontalalignment="center")
    plt.yticks(tick_marks, classes, rotation=0, fontfamily = 'Tahoma', fontsize=fontsize, verticalalignment="center")

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        text = plt.text(j, i, cm[i, j],
                 fontfamily = 'Tahoma', 
                 fontsize=12, weight='bold',
                 horizontalalignment="center", verticalalignment='center',
                 color="white" if cm[i, j] > thresh else "white")
        text.set_path_effects([path_effects.Stroke(linewidth=1, foreground='black'), 
        path_effects.Normal()]),

    
    plt.tight_layout()
    plt.ylabel('True label', fontfamily = 'Tahoma', fontsize=18, horizontalalignment="center")
    plt.xlabel('Predicted label', fontfamily = 'Tahoma', fontsize=18)

#print classification report and plot confusion matrix
plt.style.use("default")
target_names = ['Normal', 'Ulcer', 'Polyps', 'Esophagitis']
print(classification_report(Y_test,y_pred.argmax(axis=-1),
                            target_names=target_names, digits=4))

# Compute confusion matrix
cnf_matrix_test = confusion_matrix(Y_test,y_pred.argmax(axis=-1))
np.set_printoptions(precision=4)

# Plot non-normalized confusion matrix
plt.figure(figsize=(5.25, 5.25), dpi=600)
confusion_matrix_test(cnf_matrix_test, classes=target_names)
plt.tight_layout()

plt.savefig(val_norm_cm_save, 
            bbox_inches='tight', 
            dpi=dpi)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#       Normal     0.9939    0.9700    0.9818       500
#        Ulcer     0.9400    0.9400    0.9400       500
#       Polyps     0.9466    0.9580    0.9523       500
#  Esophagitis     0.9862    0.9980    0.9920       500
#
#     accuracy                         0.9665      2000
#    macro avg     0.9667    0.9665    0.9665      2000
# weighted avg     0.9667    0.9665    0.9665      2000
#
# Confusion matrix, without normalization
# [[485  14   1   0]
#  [  0 470  26   4]
#  [  3  15 479   3]
#  [  0   1   0 499]]

# %%
#Re-updated plotting format for CURVES
plt.rcParams.update({'figure.figsize': [6,6]})
plt.rcParams.update({'figure.dpi': 300})
plt.rcParams.update({'font.size': 12})
plt.rcParams.update({'legend.borderpad': 0.2})
plt.rcParams.update({'legend.fontsize': 'xx-large'})
plt.rcParams.update({'legend.frameon': True})

# %%
#ROC validation
scikitplot.metrics.plot_roc(Y_test, y_pred)
plt.title(architecture + 'CNN ' + condition + ' ' + 'do' + ' Val' + ' ROC Curve', fontsize=18, fontfamily='Tahoma')
plt.xlabel('Specificity', fontsize=18, fontfamily='Tahoma')
plt.ylabel('Sensitivity', fontsize=18, fontfamily='Tahoma')

plt.tick_params(length = 5, 
                width = 2, 
                right = True, 
                top = True, 
                labelsize = 12)

plt.rc('xtick', direction="in") 
plt.rc('ytick', direction="in") 
legend = plt.legend(loc="lower right", fontsize=15, labelspacing=1)
plt.setp(legend.texts, family = 'Tahoma')

plt.tight_layout()
plt.savefig(val_roc_save, 
            bbox_inches='tight', 
            dpi=dpi)
plt.show()

# %%
#P-R validation
scikitplot.metrics.plot_precision_recall(Y_test, y_pred)
plt.title(architecture + 'CNN ' + condition + ' ' + 'do' + ' Val' + ' P-R Curve', fontsize=18, fontfamily='Tahoma')
plt.xlabel('Recall', fontsize=18, fontfamily='Tahoma')
plt.ylabel('Precision', fontsize=18, fontfamily='Tahoma')

plt.tick_params(length = 5, 
                width = 2, 
                right = True, 
                top = True, 
                labelsize = 12)

plt.rc('xtick', direction="in") 
plt.rc('ytick', direction="in") 
plt.legend(loc="lower right", fontsize=11.5, labelspacing=0.5)
plt.setp(legend.texts, family = 'Tahoma')

plt.tight_layout()
plt.savefig(val_pr_save, 
            bbox_inches='tight', 
            dpi=dpi)
plt.show()

# %%
# Confusion Matrix (Normalized)

fontsize=12

def confusion_matrix_test(cm, classes,
                          normalize=True, #if true all values in confusion matrix is between 0 and 1
                          title=architecture + 'CNN ' + condition + ' ' + 'do' + ' Test',
                          cmap=plt.cm.binary):

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=18)
    plt.colorbar(orientation='vertical')
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=0, fontfamily = 'Tahoma', fontsize=fontsize, horizontalalignment="center")
    plt.yticks(tick_marks, classes, rotation=0, fontfamily = 'Tahoma', fontsize=fontsize, verticalalignment="center")

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        text = plt.text(j, i, '{:.2f}%'.format(cm[i, j]*100),
                 fontfamily = 'Tahoma', 
                 fontsize=9, weight='bold',
                 horizontalalignment="center", verticalalignment='center',
                 color="white" if cm[i, j] > thresh else "white")
        text.set_path_effects([path_effects.Stroke(linewidth=1, foreground='black'), 
        path_effects.Normal()]),

    
    plt.tight_layout()
    plt.ylabel('True label', fontfamily = 'Tahoma', fontsize=18, horizontalalignment="center")
    plt.xlabel('Predicted label', fontfamily = 'Tahoma', fontsize=18)

#print classification report and plot confusion matrix
plt.style.use("default")
target_names = ['Normal', 'Ulcer', 'Polyps', 'Esophagitis']
print(classification_report(test_labels,test_pred.argmax(axis=-1),
                            target_names=target_names, digits=4))

# Compute confusion matrix
cnf_matrix_test = confusion_matrix(test_labels,test_pred.argmax(axis=-1))
np.set_printoptions(precision=4)

# Plot non-normalized confusion matrix
plt.figure(figsize=(5.25, 5.25), dpi=600)
confusion_matrix_test(cnf_matrix_test, classes=target_names)
plt.tight_layout()

plt.savefig(test_cm_save, 
            bbox_inches='tight', 
            dpi=dpi)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#       Normal     1.0000    0.9850    0.9924       200
#        Ulcer     0.9596    0.9500    0.9548       200
#       Polyps     0.9653    0.9750    0.9701       200
#  Esophagitis     0.9852    1.0000    0.9926       200
#
#     accuracy                         0.9775       800
#    macro avg     0.9775    0.9775    0.9775       800
# weighted avg     0.9775    0.9775    0.9775       800
#
# Normalized confusion matrix
# [[0.985 0.015 0.    0.   ]
#  [0.    0.95  0.035 0.015]
#  [0.    0.025 0.975 0.   ]
#  [0.    0.    0.    1.   ]]

# %%
#Confusion Matrix

fontsize=12

def confusion_matrix_test(cm, classes,
                          normalize=False, #if true all values in confusion matrix is between 0 and 1
                          title=architecture + ' ' + condition + ' ' + 'do' + ' Test',
                          cmap=plt.cm.binary):

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=18)
    plt.colorbar(orientation='vertical')
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=0, fontfamily = 'Tahoma', fontsize=fontsize, horizontalalignment="center")
    plt.yticks(tick_marks, classes, rotation=0, fontfamily = 'Tahoma', fontsize=fontsize, verticalalignment="center")

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        text = plt.text(j, i, cm[i, j],
                 fontfamily = 'Tahoma', 
                 fontsize=12, weight='bold',
                 horizontalalignment="center", verticalalignment='center',
                 color="white" if cm[i, j] > thresh else "white")
        text.set_path_effects([path_effects.Stroke(linewidth=1, foreground='black'), 
        path_effects.Normal()]),

    
    plt.tight_layout()
    plt.ylabel('True label', fontfamily = 'Tahoma', fontsize=18, horizontalalignment="center")
    plt.xlabel('Predicted label', fontfamily = 'Tahoma', fontsize=18)

#print classification report and plot confusion matrix
plt.style.use("default")
target_names = ['Normal', 'Ulcer', 'Polyps', 'Esophagitis']
print(classification_report(test_labels, test_pred.argmax(axis=-1),
                            target_names=target_names, digits=4))

# Compute confusion matrix
cnf_matrix_test = confusion_matrix(test_labels, test_pred.argmax(axis=-1))
np.set_printoptions(precision=4)

# Plot non-normalized confusion matrix
plt.figure(figsize=(5.25, 5.25), dpi=600)
confusion_matrix_test(cnf_matrix_test, classes=target_names)
plt.tight_layout()

plt.savefig(test_norm_cm_save, 
            bbox_inches='tight', 
            dpi=dpi)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#       Normal     1.0000    0.9850    0.9924       200
#        Ulcer     0.9596    0.9500    0.9548       200
#       Polyps     0.9653    0.9750    0.9701       200
#  Esophagitis     0.9852    1.0000    0.9926       200
#
#     accuracy                         0.9775       800
#    macro avg     0.9775    0.9775    0.9775       800
# weighted avg     0.9775    0.9775    0.9775       800
#
# Confusion matrix, without normalization
# [[197   3   0   0]
#  [  0 190   7   3]
#  [  0   5 195   0]
#  [  0   0   0 200]]

# %%
#re-update plot for CURVES
plt.rcParams.update({'figure.figsize': [6,6]})
plt.rcParams.update({'figure.dpi': 300})
plt.rcParams.update({'font.size': 12})
plt.rcParams.update({'legend.borderpad': 0.2})
plt.rcParams.update({'legend.fontsize': 'xx-large'})
plt.rcParams.update({'legend.frameon': True})

# %%
#ROC test
scikitplot.metrics.plot_roc(test_labels, test_pred)
plt.title(architecture + ' ' + condition + ' ' + 'do' + ' Test' + ' ROC Curve', fontsize=18, fontfamily='Tahoma')
plt.xlabel('Specificity', fontsize=18, fontfamily='Tahoma')
plt.ylabel('Sensitivity', fontsize=18, fontfamily='Tahoma')

plt.tick_params(length = 5, 
                width = 2, 
                right = True, 
                top = True, 
                labelsize = 12)

plt.rc('xtick', direction="in") 
plt.rc('ytick', direction="in") 
legend = plt.legend(loc="lower right", fontsize=15, labelspacing=1)
plt.setp(legend.texts, family = 'Tahoma')

plt.tight_layout()
plt.savefig(test_roc_save, 
            bbox_inches='tight', 
            dpi=dpi)
plt.show()

# %%
#P-R test
scikitplot.metrics.plot_precision_recall(test_labels, test_pred)
plt.title(architecture + ' ' + condition + ' ' + 'do' + ' Test' + ' P-R Curve', fontsize=18, fontfamily='Tahoma')
plt.xlabel('Recall', fontsize=18, fontfamily='Tahoma')
plt.ylabel('Precision', fontsize=18, fontfamily='Tahoma')

plt.tick_params(length = 5, 
                width = 2, 
                right = True, 
                top = True, 
                labelsize = 12)

plt.rc('xtick', direction="in") 
plt.rc('ytick', direction="in") 
plt.legend(loc="lower right", fontsize=11.5, labelspacing=0.5)
plt.setp(legend.texts, family = 'Tahoma')

plt.tight_layout()
plt.savefig(test_pr_save, 
            bbox_inches='tight', 
            dpi=dpi)
plt.show()

# %% [markdown]
# <h2>Computational cost</h2>

# %%
#Computational Cost
def cost_compute():
    from keras_flops import get_flops
    from keras.utils.layer_utils import count_params
    flops  = float("{0:.2f}".format(get_flops(Model(model.input, model.output), batch_size=1)/ 10 ** 9))
    params = float("{0:.2f}".format(model.count_params() / 10 ** 6))
    trainable_count = float("{0:.2f}".format(count_params(model.trainable_weights) / 10 ** 6))
    model_file_size = float("{0:.2f}".format(os.stat('models/' + architecture + 'CNN' + '_'+ condition + '_do/' + 'model.h5').st_size / 10 ** 6))
    
    print("COMPUTATIONAL EFFICIENCY REPORT")
    print("===============================")
    print()
    print('The evaluated: ' + architecture + 'CNN ' + condition + ' ' + 'do** ')
    print("-------------------------------")
    print('* Required ' + str(flops) + 'M FLOPS to compute.')
    print('* Used exactly ' + str(trainable_count) + 'M parameters ' + 'to train.')
    print('* Contained ' + str(params) + 'M parameters ' +  'overall.')
    print('* Consumed a storage size of around ' + str(model_file_size) + 'MB.')

cost_compute()
# Out:
# COMPUTATIONAL EFFICIENCY REPORT
# ===============================
#
# The evaluated: MFuReCNN alpha do**
# -------------------------------
# * Required 7.8M FLOPS to compute.
# * Used exactly 4.83M parameters to train.
# * Contained 9.47M parameters overall.
# * Consumed a storage size of around 77.8MB.
